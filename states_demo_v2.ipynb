# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### PULLING IN TABLES

# %% [markdown]
# #### YT

# %%
yt_female_2016 = pd.read_csv('actual_data/yt_female_pop_2016.csv')
yt_female_2017 = pd.read_csv('actual_data/yt_female_pop_2017.csv')
yt_female_2018 = pd.read_csv('actual_data/yt_female_pop_2018.csv')
yt_female_2019 = pd.read_csv('actual_data/yt_female_pop_2019.csv')
yt_female_2020 = pd.read_csv('actual_data/yt_female_pop_2020.csv')

# %%
yt_female_2016['year'] = 2016
yt_female_2017['year'] = 2017
yt_female_2018['year'] = 2018
yt_female_2019['year'] = 2019
yt_female_2020['year'] = 2020

# %%
ay_yt_female = pd.concat([yt_female_2016,yt_female_2017,yt_female_2018,yt_female_2019,yt_female_2020]).reset_index(drop=True)

# %% [markdown]
# #### AA

# %%
aa_female_2016 = pd.read_csv('actual_data/aa_female_pop_2016.csv')
aa_female_2017 = pd.read_csv('actual_data/aa_female_pop_2017.csv')
aa_female_2018 = pd.read_csv('actual_data/aa_female_pop_2018.csv')
aa_female_2019 = pd.read_csv('actual_data/aa_female_pop_2019.csv')
aa_female_2020 = pd.read_csv('actual_data/aa_female_pop_2020.csv')

# %%
aa_female_2016['year'] = 2016
aa_female_2017['year'] = 2017
aa_female_2018['year'] = 2018
aa_female_2019['year'] = 2019
aa_female_2020['year'] = 2020

# %%
ay_aa_female = pd.concat([aa_female_2016,aa_female_2017,aa_female_2018,aa_female_2019,aa_female_2020]).reset_index(drop=True)

# %% [markdown]
# #### HIS

# %%
his_female_2016 = pd.read_csv('actual_data/his_female_pop_2016.csv')
his_female_2017 = pd.read_csv('actual_data/his_female_pop_2017.csv')
his_female_2018 = pd.read_csv('actual_data/his_female_pop_2018.csv')
his_female_2019 = pd.read_csv('actual_data/his_female_pop_2019.csv')
his_female_2020 = pd.read_csv('actual_data/his_female_pop_2020.csv')

# %%
his_female_2016['year'] = 2016
his_female_2017['year'] = 2017
his_female_2018['year'] = 2018
his_female_2019['year'] = 2019
his_female_2020['year'] = 2020

# %%
ay_his_female = pd.concat([his_female_2016,his_female_2017,his_female_2018,his_female_2019,his_female_2020]).reset_index(drop=True)

# %% [markdown]
# #### AIAN

# %%
aian_female_2016 = pd.read_csv('actual_data/aian_female_pop_2016.csv')
aian_female_2017 = pd.read_csv('actual_data/aian_female_pop_2017.csv')
aian_female_2018 = pd.read_csv('actual_data/aian_female_pop_2018.csv')
aian_female_2019 = pd.read_csv('actual_data/aian_female_pop_2019.csv')
aian_female_2020 = pd.read_csv('actual_data/aian_female_pop_2020.csv')

# %%
aian_female_2016['year'] = 2016
aian_female_2017['year'] = 2017
aian_female_2018['year'] = 2018
aian_female_2019['year'] = 2019
aian_female_2020['year'] = 2020

# %%
ay_aian_female = pd.concat([aian_female_2016,aian_female_2017,aian_female_2018,aian_female_2019,aian_female_2020]).reset_index(drop=True)

# %% [markdown]
# #### ASIAN

# %%
asian_female_2016 = pd.read_csv('actual_data/asian_female_pop_2016.csv')
asian_female_2017 = pd.read_csv('actual_data/asian_female_pop_2017.csv')
asian_female_2018 = pd.read_csv('actual_data/asian_female_pop_2018.csv')
asian_female_2019 = pd.read_csv('actual_data/asian_female_pop_2019.csv')
asian_female_2020 = pd.read_csv('actual_data/asian_female_pop_2020.csv')

# %%
asian_female_2016['year'] = 2016
asian_female_2017['year'] = 2017
asian_female_2018['year'] = 2018
asian_female_2019['year'] = 2019
asian_female_2020['year'] = 2020

# %%
ay_asian_female = pd.concat([asian_female_2016,asian_female_2017,asian_female_2018,asian_female_2019,asian_female_2020]).reset_index(drop=True)

# %% [markdown]
# #### NHOPI

# %%
nhopi_female_2016 = pd.read_csv('actual_data/nhopi_female_pop_2016.csv')
nhopi_female_2017 = pd.read_csv('actual_data/nhopi_female_pop_2017.csv')
nhopi_female_2018 = pd.read_csv('actual_data/nhopi_female_pop_2018.csv')
nhopi_female_2019 = pd.read_csv('actual_data/nhopi_female_pop_2019.csv')
nhopi_female_2020 = pd.read_csv('actual_data/nhopi_female_pop_2020.csv')

# %%
nhopi_female_2016['year'] = 2016
nhopi_female_2017['year'] = 2017
nhopi_female_2018['year'] = 2018
nhopi_female_2019['year'] = 2019
nhopi_female_2020['year'] = 2020

# %%
ay_nhopi_female = pd.concat([nhopi_female_2016,nhopi_female_2017,nhopi_female_2018,nhopi_female_2019,nhopi_female_2020]).reset_index(drop=True)

# %% [markdown]
# #### TWO

# %%
two_female_2016 = pd.read_csv('actual_data/two_female_pop_2016.csv')
two_female_2017 = pd.read_csv('actual_data/two_female_pop_2017.csv')
two_female_2018 = pd.read_csv('actual_data/two_female_pop_2018.csv')
two_female_2019 = pd.read_csv('actual_data/two_female_pop_2019.csv')
two_female_2020 = pd.read_csv('actual_data/two_female_pop_2020.csv')

# %%
two_female_2017.head(55)
# Out:
#         Label (Grouping)     Total: Total:!!Female:!!15 to 17 years  \
# 0                Alabama        NaN                             NaN
# 1               Estimate     88,834                           2,789
# 2                 Alaska        NaN                             NaN
# 3               Estimate     62,713                           1,901
# 4                Arizona        NaN                             NaN
# 5               Estimate    237,908                           7,579
# 6               Arkansas        NaN                             NaN
# 7               Estimate     71,822                           2,423
# 8             California        NaN                             NaN
# 9               Estimate  1,834,714                          56,931
# 10              Colorado        NaN                             NaN
# 11              Estimate    188,909                           5,847
# 12           Connecticut        NaN                             NaN
# ...

# %%
two_female_2018.head()
# Out:
#   Label (Grouping)  Total: Total:!!Female:!!15 to 17 years  \
# 0          Alabama     NaN                             NaN
# 1         Estimate  91,619                           2,897
# 2           Alaska     NaN                             NaN
# 3         Estimate  62,461                           2,081
# 4          Arizona     NaN                             NaN
#
#   Total:!!Female:!!18 and 19 years Total:!!Female:!!20 to 24 years  \
# 0                              NaN                             NaN
# 1                            1,612                           3,661
# 2                              NaN                             NaN
# 3                              969                           2,352
# 4                              NaN                             NaN
#
#   Total:!!Female:!!25 to 29 years Total:!!Female:!!30 to 34 years  \
# 0                             NaN                             NaN
# 1                           2,718                           2,619
# ...

# %%
two_female_2016['year'] = 2016
two_female_2017['year'] = 2017
two_female_2018['year'] = 2018
two_female_2019['year'] = 2019
two_female_2020['year'] = 2020

# %%
ay_two_female = pd.concat([two_female_2016,two_female_2017,two_female_2018,two_female_2019,two_female_2020]).reset_index(drop=True)

# %% [markdown]
# ### ORGANIZING TABLES

# %% [markdown]
# #### YT

# %%
ay_yt_female['Total:'] = ay_yt_female['Total:'].shift(-1).str.replace(',','')
ay_yt_female['Total:!!Female:!!15 to 17 years'] = ay_yt_female['Total:!!Female:!!15 to 17 years'].shift(-1).str.replace(',','')
ay_yt_female['Total:!!Female:!!18 and 19 years'] = ay_yt_female['Total:!!Female:!!18 and 19 years'].shift(-1).str.replace(',','')
ay_yt_female['Total:!!Female:!!20 to 24 years'] = ay_yt_female['Total:!!Female:!!20 to 24 years'].shift(-1).str.replace(',','')
ay_yt_female['Total:!!Female:!!25 to 29 years'] = ay_yt_female['Total:!!Female:!!25 to 29 years'].shift(-1).str.replace(',','')
ay_yt_female['Total:!!Female:!!30 to 34 years'] = ay_yt_female['Total:!!Female:!!30 to 34 years'].shift(-1).str.replace(',','')
ay_yt_female['Total:!!Female:!!35 to 44 years'] = ay_yt_female['Total:!!Female:!!35 to 44 years'].shift(-1).str.replace(',','')
ay_yt_female['Total:!!Female:!!45 to 54 years'] = ay_yt_female['Total:!!Female:!!45 to 54 years'].shift(-1).str.replace(',','')
ay_yt_female = ay_yt_female.dropna().reset_index(drop=True)

# %%
ay_yt_female['Total:'] = ay_yt_female['Total:'].astype(int)
ay_yt_female['Total:!!Female:!!15 to 17 years'] = ay_yt_female['Total:!!Female:!!15 to 17 years'].astype(int)
ay_yt_female['Total:!!Female:!!18 and 19 years'] = ay_yt_female['Total:!!Female:!!18 and 19 years'].astype(int)
ay_yt_female['Total:!!Female:!!20 to 24 years'] = ay_yt_female['Total:!!Female:!!20 to 24 years'].astype(int)
ay_yt_female['Total:!!Female:!!25 to 29 years'] = ay_yt_female['Total:!!Female:!!25 to 29 years'].astype(int)
ay_yt_female['Total:!!Female:!!30 to 34 years'] = ay_yt_female['Total:!!Female:!!30 to 34 years'].astype(int)
ay_yt_female['Total:!!Female:!!35 to 44 years'] = ay_yt_female['Total:!!Female:!!35 to 44 years'].astype(int)
ay_yt_female['Total:!!Female:!!45 to 54 years'] = ay_yt_female['Total:!!Female:!!45 to 54 years'].astype(int)

# %%
ay_yt_female['yt_female_pop_15_54'] = ay_yt_female['Total:!!Female:!!15 to 17 years'] + ay_yt_female['Total:!!Female:!!18 and 19 years'] + ay_yt_female['Total:!!Female:!!20 to 24 years']
ay_yt_female['Total:!!Female:!!25 to 29 years'] + ay_yt_female['Total:!!Female:!!30 to 34 years'] + ay_yt_female['Total:!!Female:!!35 to 44 years'] + ay_yt_female['Total:!!Female:!!45 to 54 years']
# Out:
# 0        642307
# 1         97546
# 2        971339
# 3        439199
# 4       4701170
#          ...
# 260      307816
# 261      896032
# 262       94908
# 263      382411
# 264    43694025
# Length: 265, dtype: int32

# %%
ay_yt_female = ay_yt_female[['Label (Grouping)','Total:','yt_female_pop_15_54','year']].rename(columns = {'Label (Grouping)':'state','Total:':'yt_total_pop'})

# %% [markdown]
# #### AA

# %%
ay_aa_female['Total:'] = ay_aa_female['Total:'].shift(-1).str.replace(',','')
ay_aa_female['Total:!!Female:!!15 to 17 years'] = ay_aa_female['Total:!!Female:!!15 to 17 years'].shift(-1).str.replace(',','')
ay_aa_female['Total:!!Female:!!18 and 19 years'] = ay_aa_female['Total:!!Female:!!18 and 19 years'].shift(-1).str.replace(',','')
ay_aa_female['Total:!!Female:!!20 to 24 years'] = ay_aa_female['Total:!!Female:!!20 to 24 years'].shift(-1).str.replace(',','')
ay_aa_female['Total:!!Female:!!25 to 29 years'] = ay_aa_female['Total:!!Female:!!25 to 29 years'].shift(-1).str.replace(',','')
ay_aa_female['Total:!!Female:!!30 to 34 years'] = ay_aa_female['Total:!!Female:!!30 to 34 years'].shift(-1).str.replace(',','')
ay_aa_female['Total:!!Female:!!35 to 44 years'] = ay_aa_female['Total:!!Female:!!35 to 44 years'].shift(-1).str.replace(',','')
ay_aa_female['Total:!!Female:!!45 to 54 years'] = ay_aa_female['Total:!!Female:!!45 to 54 years'].shift(-1).str.replace(',','')
ay_aa_female = ay_aa_female.dropna().reset_index(drop=True)

# %%
ay_aa_female['Total:'] = ay_aa_female['Total:'].astype(int)
ay_aa_female['Total:!!Female:!!15 to 17 years'] = ay_aa_female['Total:!!Female:!!15 to 17 years'].astype(int)
ay_aa_female['Total:!!Female:!!18 and 19 years'] = ay_aa_female['Total:!!Female:!!18 and 19 years'].astype(int)
ay_aa_female['Total:!!Female:!!20 to 24 years'] = ay_aa_female['Total:!!Female:!!20 to 24 years'].astype(int)
ay_aa_female['Total:!!Female:!!25 to 29 years'] = ay_aa_female['Total:!!Female:!!25 to 29 years'].astype(int)
ay_aa_female['Total:!!Female:!!30 to 34 years'] = ay_aa_female['Total:!!Female:!!30 to 34 years'].astype(int)
ay_aa_female['Total:!!Female:!!35 to 44 years'] = ay_aa_female['Total:!!Female:!!35 to 44 years'].astype(int)
ay_aa_female['Total:!!Female:!!45 to 54 years'] = ay_aa_female['Total:!!Female:!!45 to 54 years'].astype(int)

# %%
ay_aa_female['aa_female_pop_15_54'] = ay_aa_female['Total:!!Female:!!15 to 17 years'] + ay_aa_female['Total:!!Female:!!18 and 19 years'] + ay_aa_female['Total:!!Female:!!20 to 24 years']
ay_aa_female['Total:!!Female:!!25 to 29 years'] + ay_aa_female['Total:!!Female:!!30 to 34 years'] + ay_aa_female['Total:!!Female:!!35 to 44 years'] + ay_aa_female['Total:!!Female:!!45 to 54 years']
# Out:
# 0       278059
# 1         4362
# 2        57139
# 3        95620
# 4       474394
#         ...
# 260      10625
# 261      75202
# 262        802
# 263      73722
# 264    8803618
# Length: 265, dtype: int32

# %%
ay_aa_female = ay_aa_female[['Label (Grouping)','Total:','aa_female_pop_15_54','year']].rename(columns = {'Label (Grouping)':'state','Total:':'aa_total_pop'})

# %% [markdown]
# #### HIS

# %%
ay_his_female['Total:'] = ay_his_female['Total:'].shift(-1).str.replace(',','')
ay_his_female['Total:!!Female:!!15 to 17 years'] = ay_his_female['Total:!!Female:!!15 to 17 years'].shift(-1).str.replace(',','')
ay_his_female['Total:!!Female:!!18 and 19 years'] = ay_his_female['Total:!!Female:!!18 and 19 years'].shift(-1).str.replace(',','')
ay_his_female['Total:!!Female:!!20 to 24 years'] = ay_his_female['Total:!!Female:!!20 to 24 years'].shift(-1).str.replace(',','')
ay_his_female['Total:!!Female:!!25 to 29 years'] = ay_his_female['Total:!!Female:!!25 to 29 years'].shift(-1).str.replace(',','')
ay_his_female['Total:!!Female:!!30 to 34 years'] = ay_his_female['Total:!!Female:!!30 to 34 years'].shift(-1).str.replace(',','')
ay_his_female['Total:!!Female:!!35 to 44 years'] = ay_his_female['Total:!!Female:!!35 to 44 years'].shift(-1).str.replace(',','')
ay_his_female['Total:!!Female:!!45 to 54 years'] = ay_his_female['Total:!!Female:!!45 to 54 years'].shift(-1).str.replace(',','')
ay_his_female = ay_his_female.dropna().reset_index(drop=True)

# %%
ay_his_female['Total:'] = ay_his_female['Total:'].astype(int)
ay_his_female['Total:!!Female:!!15 to 17 years'] = ay_his_female['Total:!!Female:!!15 to 17 years'].astype(int)
ay_his_female['Total:!!Female:!!18 and 19 years'] = ay_his_female['Total:!!Female:!!18 and 19 years'].astype(int)
ay_his_female['Total:!!Female:!!20 to 24 years'] = ay_his_female['Total:!!Female:!!20 to 24 years'].astype(int)
ay_his_female['Total:!!Female:!!25 to 29 years'] = ay_his_female['Total:!!Female:!!25 to 29 years'].astype(int)
ay_his_female['Total:!!Female:!!30 to 34 years'] = ay_his_female['Total:!!Female:!!30 to 34 years'].astype(int)
ay_his_female['Total:!!Female:!!35 to 44 years'] = ay_his_female['Total:!!Female:!!35 to 44 years'].astype(int)
ay_his_female['Total:!!Female:!!45 to 54 years'] = ay_his_female['Total:!!Female:!!45 to 54 years'].astype(int)

# %%
ay_his_female['his_female_pop_15_54'] = ay_his_female['Total:!!Female:!!15 to 17 years'] + ay_his_female['Total:!!Female:!!18 and 19 years'] + ay_his_female['Total:!!Female:!!20 to 24 years']
ay_his_female['Total:!!Female:!!25 to 29 years'] + ay_his_female['Total:!!Female:!!30 to 34 years'] + ay_his_female['Total:!!Female:!!35 to 44 years'] + ay_his_female['Total:!!Female:!!45 to 54 years']
# Out:
# 0         35886
# 1          9321
# 2        401981
# 3         39290
# 4       3053295
#          ...
# 260        5220
# 261       75504
# 262       10348
# 263      637207
# 264    12063497
# Length: 265, dtype: int32

# %%
ay_his_female = ay_his_female[['Label (Grouping)','Total:','his_female_pop_15_54','year']].rename(columns = {'Label (Grouping)':'state','Total:':'his_total_pop'})

# %% [markdown]
# #### AIAN

# %%
ay_aian_female['Total:'] = ay_aian_female['Total:'].shift(-1).str.replace(',','')
ay_aian_female['Total:!!Female:!!15 to 17 years'] = ay_aian_female['Total:!!Female:!!15 to 17 years'].shift(-1).str.replace(',','')
ay_aian_female['Total:!!Female:!!18 and 19 years'] = ay_aian_female['Total:!!Female:!!18 and 19 years'].shift(-1).str.replace(',','')
ay_aian_female['Total:!!Female:!!20 to 24 years'] = ay_aian_female['Total:!!Female:!!20 to 24 years'].shift(-1).str.replace(',','')
ay_aian_female['Total:!!Female:!!25 to 29 years'] = ay_aian_female['Total:!!Female:!!25 to 29 years'].shift(-1).str.replace(',','')
ay_aian_female['Total:!!Female:!!30 to 34 years'] = ay_aian_female['Total:!!Female:!!30 to 34 years'].shift(-1).str.replace(',','')
ay_aian_female['Total:!!Female:!!35 to 44 years'] = ay_aian_female['Total:!!Female:!!35 to 44 years'].shift(-1).str.replace(',','')
ay_aian_female['Total:!!Female:!!45 to 54 years'] = ay_aian_female['Total:!!Female:!!45 to 54 years'].shift(-1).str.replace(',','')
ay_aian_female = ay_aian_female.dropna().reset_index(drop=True)

# %%
ay_aian_female['Total:'] = ay_aian_female['Total:'].astype(int)
ay_aian_female['Total:!!Female:!!15 to 17 years'] = ay_aian_female['Total:!!Female:!!15 to 17 years'].astype(int)
ay_aian_female['Total:!!Female:!!18 and 19 years'] = ay_aian_female['Total:!!Female:!!18 and 19 years'].astype(int)
ay_aian_female['Total:!!Female:!!20 to 24 years'] = ay_aian_female['Total:!!Female:!!20 to 24 years'].astype(int)
ay_aian_female['Total:!!Female:!!25 to 29 years'] = ay_aian_female['Total:!!Female:!!25 to 29 years'].astype(int)
ay_aian_female['Total:!!Female:!!30 to 34 years'] = ay_aian_female['Total:!!Female:!!30 to 34 years'].astype(int)
ay_aian_female['Total:!!Female:!!35 to 44 years'] = ay_aian_female['Total:!!Female:!!35 to 44 years'].astype(int)
ay_aian_female['Total:!!Female:!!45 to 54 years'] = ay_aian_female['Total:!!Female:!!45 to 54 years'].astype(int)

# %%
ay_aian_female['aian_female_pop_15_54'] = ay_aian_female['Total:!!Female:!!15 to 17 years'] + ay_aian_female['Total:!!Female:!!18 and 19 years'] + ay_aian_female['Total:!!Female:!!20 to 24 years']
ay_aian_female['Total:!!Female:!!25 to 29 years'] + ay_aian_female['Total:!!Female:!!30 to 34 years'] + ay_aian_female['Total:!!Female:!!35 to 44 years'] + ay_aian_female['Total:!!Female:!!45 to 54 years']
# Out:
# 0        5758
# 1       19736
# 2       59416
# 3        4188
# 4       58656
#         ...
# 260       737
# 261      9437
# 262      2453
# 263      1014
# 264    531955
# Length: 265, dtype: int32

# %%
ay_aian_female = ay_aian_female[['Label (Grouping)','Total:','aian_female_pop_15_54','year']].rename(columns = {'Label (Grouping)':'state','Total:':'aian_total_pop'})

# %% [markdown]
# #### ASIAN

# %%
ay_asian_female['Total:'] = ay_asian_female['Total:'].shift(-1).str.replace(',','')
ay_asian_female['Total:!!Female:!!15 to 17 years'] = ay_asian_female['Total:!!Female:!!15 to 17 years'].shift(-1).str.replace(',','')
ay_asian_female['Total:!!Female:!!18 and 19 years'] = ay_asian_female['Total:!!Female:!!18 and 19 years'].shift(-1).str.replace(',','')
ay_asian_female['Total:!!Female:!!20 to 24 years'] = ay_asian_female['Total:!!Female:!!20 to 24 years'].shift(-1).str.replace(',','')
ay_asian_female['Total:!!Female:!!25 to 29 years'] = ay_asian_female['Total:!!Female:!!25 to 29 years'].shift(-1).str.replace(',','')
ay_asian_female['Total:!!Female:!!30 to 34 years'] = ay_asian_female['Total:!!Female:!!30 to 34 years'].shift(-1).str.replace(',','')
ay_asian_female['Total:!!Female:!!35 to 44 years'] = ay_asian_female['Total:!!Female:!!35 to 44 years'].shift(-1).str.replace(',','')
ay_asian_female['Total:!!Female:!!45 to 54 years'] = ay_asian_female['Total:!!Female:!!45 to 54 years'].shift(-1).str.replace(',','')
ay_asian_female = ay_asian_female.dropna().reset_index(drop=True)

# %%
ay_asian_female['Total:'] = ay_asian_female['Total:'].astype(int)
ay_asian_female['Total:!!Female:!!15 to 17 years'] = ay_asian_female['Total:!!Female:!!15 to 17 years'].astype(int)
ay_asian_female['Total:!!Female:!!18 and 19 years'] = ay_asian_female['Total:!!Female:!!18 and 19 years'].astype(int)
ay_asian_female['Total:!!Female:!!20 to 24 years'] = ay_asian_female['Total:!!Female:!!20 to 24 years'].astype(int)
ay_asian_female['Total:!!Female:!!25 to 29 years'] = ay_asian_female['Total:!!Female:!!25 to 29 years'].astype(int)
ay_asian_female['Total:!!Female:!!30 to 34 years'] = ay_asian_female['Total:!!Female:!!30 to 34 years'].astype(int)
ay_asian_female['Total:!!Female:!!35 to 44 years'] = ay_asian_female['Total:!!Female:!!35 to 44 years'].astype(int)
ay_asian_female['Total:!!Female:!!45 to 54 years'] = ay_asian_female['Total:!!Female:!!45 to 54 years'].astype(int)

# %%
ay_asian_female['asian_female_pop_15_54'] = ay_asian_female['Total:!!Female:!!15 to 17 years'] + ay_asian_female['Total:!!Female:!!18 and 19 years'] + ay_asian_female['Total:!!Female:!!20 to 24 years']
ay_asian_female['Total:!!Female:!!25 to 29 years'] + ay_asian_female['Total:!!Female:!!30 to 34 years'] + ay_asian_female['Total:!!Female:!!35 to 44 years'] + ay_asian_female['Total:!!Female:!!45 to 54 years']
# Out:
# 0        15700
# 1        10417
# 2        53157
# 3        10873
# 4      1302892
#         ...
# 260       3624
# 261      39023
# 262       1493
# 263       1788
# 264    4534751
# Length: 265, dtype: int32

# %%
ay_asian_female = ay_asian_female[['Label (Grouping)','Total:','asian_female_pop_15_54','year']].rename(columns = {'Label (Grouping)':'state','Total:':'asian_total_pop'})

# %% [markdown]
# #### NHOPI

# %%
ay_nhopi_female['Total:'] = ay_nhopi_female['Total:'].shift(-1).str.replace(',','')
ay_nhopi_female['Total:!!Female:!!15 to 17 years'] = ay_nhopi_female['Total:!!Female:!!15 to 17 years'].shift(-1).str.replace(',','')
ay_nhopi_female['Total:!!Female:!!18 and 19 years'] = ay_nhopi_female['Total:!!Female:!!18 and 19 years'].shift(-1).str.replace(',','')
ay_nhopi_female['Total:!!Female:!!20 to 24 years'] = ay_nhopi_female['Total:!!Female:!!20 to 24 years'].shift(-1).str.replace(',','')
ay_nhopi_female['Total:!!Female:!!25 to 29 years'] = ay_nhopi_female['Total:!!Female:!!25 to 29 years'].shift(-1).str.replace(',','')
ay_nhopi_female['Total:!!Female:!!30 to 34 years'] = ay_nhopi_female['Total:!!Female:!!30 to 34 years'].shift(-1).str.replace(',','')
ay_nhopi_female['Total:!!Female:!!35 to 44 years'] = ay_nhopi_female['Total:!!Female:!!35 to 44 years'].shift(-1).str.replace(',','')
ay_nhopi_female['Total:!!Female:!!45 to 54 years'] = ay_nhopi_female['Total:!!Female:!!45 to 54 years'].shift(-1).str.replace(',','')
ay_nhopi_female = ay_nhopi_female.dropna().reset_index(drop=True)

# %%
ay_nhopi_female['Total:'] = ay_nhopi_female['Total:'].astype(int)
ay_nhopi_female['Total:!!Female:!!15 to 17 years'] = ay_nhopi_female['Total:!!Female:!!15 to 17 years'].astype(int)
ay_nhopi_female['Total:!!Female:!!18 and 19 years'] = ay_nhopi_female['Total:!!Female:!!18 and 19 years'].astype(int)
ay_nhopi_female['Total:!!Female:!!20 to 24 years'] = ay_nhopi_female['Total:!!Female:!!20 to 24 years'].astype(int)
ay_nhopi_female['Total:!!Female:!!25 to 29 years'] = ay_nhopi_female['Total:!!Female:!!25 to 29 years'].astype(int)
ay_nhopi_female['Total:!!Female:!!30 to 34 years'] = ay_nhopi_female['Total:!!Female:!!30 to 34 years'].astype(int)
ay_nhopi_female['Total:!!Female:!!35 to 44 years'] = ay_nhopi_female['Total:!!Female:!!35 to 44 years'].astype(int)
ay_nhopi_female['Total:!!Female:!!45 to 54 years'] = ay_nhopi_female['Total:!!Female:!!45 to 54 years'].astype(int)

# %%
ay_nhopi_female['nhopi_female_pop_15_54'] = ay_nhopi_female['Total:!!Female:!!15 to 17 years'] + ay_nhopi_female['Total:!!Female:!!18 and 19 years'] + ay_nhopi_female['Total:!!Female:!!20 to 24 years']
ay_nhopi_female['Total:!!Female:!!25 to 29 years'] + ay_nhopi_female['Total:!!Female:!!30 to 34 years'] + ay_nhopi_female['Total:!!Female:!!35 to 44 years'] + ay_nhopi_female['Total:!!Female:!!45 to 54 years']
# Out:
# 0         589
# 1        1875
# 2        2753
# 3        1325
# 4       35696
#         ...
# 260        14
# 261       498
# 262       132
# 263        24
# 264    133294
# Length: 265, dtype: int32

# %%
ay_nhopi_female = ay_nhopi_female[['Label (Grouping)','Total:','nhopi_female_pop_15_54','year']].rename(columns = {'Label (Grouping)':'state','Total:':'nhopi_total_pop'})

# %% [markdown]
# #### TWO

# %%
ay_two_female['Total:'] = ay_two_female['Total:'].shift(-1).str.replace(',','')
ay_two_female['Total:!!Female:!!15 to 17 years'] = ay_two_female['Total:!!Female:!!15 to 17 years'].shift(-1).str.replace(',','')
ay_two_female['Total:!!Female:!!18 and 19 years'] = ay_two_female['Total:!!Female:!!18 and 19 years'].shift(-1).str.replace(',','')
ay_two_female['Total:!!Female:!!20 to 24 years'] = ay_two_female['Total:!!Female:!!20 to 24 years'].shift(-1).str.replace(',','')
ay_two_female['Total:!!Female:!!25 to 29 years'] = ay_two_female['Total:!!Female:!!25 to 29 years'].shift(-1).str.replace(',','')
ay_two_female['Total:!!Female:!!30 to 34 years'] = ay_two_female['Total:!!Female:!!30 to 34 years'].shift(-1).str.replace(',','')
ay_two_female['Total:!!Female:!!35 to 44 years'] = ay_two_female['Total:!!Female:!!35 to 44 years'].shift(-1).str.replace(',','')
ay_two_female['Total:!!Female:!!45 to 54 years'] = ay_two_female['Total:!!Female:!!45 to 54 years'].shift(-1).str.replace(',','')
ay_two_female = ay_two_female.dropna().reset_index(drop=True)

# %%
#ay_two_female.columns

# %%
#ay_two_female_drop = ay_two_female.loc[ay_two_female['Total:!!Female:!!45 to 54 years'].isna()]

# %%
#ay_two_female_drop.loc[ay_two_female_drop['Label (Grouping)'] == 'Alabama']

# %%
ay_two_female['Total:'] = ay_two_female['Total:'].astype(int)
ay_two_female['Total:!!Female:!!15 to 17 years'] = ay_two_female['Total:!!Female:!!15 to 17 years'].astype(int)
ay_two_female['Total:!!Female:!!18 and 19 years'] = ay_two_female['Total:!!Female:!!18 and 19 years'].astype(int)
ay_two_female['Total:!!Female:!!20 to 24 years'] = ay_two_female['Total:!!Female:!!20 to 24 years'].astype(int)
ay_two_female['Total:!!Female:!!25 to 29 years'] = ay_two_female['Total:!!Female:!!25 to 29 years'].astype(int)
ay_two_female['Total:!!Female:!!30 to 34 years'] = ay_two_female['Total:!!Female:!!30 to 34 years'].astype(int)
ay_two_female['Total:!!Female:!!35 to 44 years'] = ay_two_female['Total:!!Female:!!35 to 44 years'].astype(int)
ay_two_female['Total:!!Female:!!45 to 54 years'] = ay_two_female['Total:!!Female:!!45 to 54 years'].astype(int)

# %%
ay_two_female['two_female_pop_15_54'] = ay_two_female['Total:!!Female:!!15 to 17 years'] + ay_two_female['Total:!!Female:!!18 and 19 years'] + ay_two_female['Total:!!Female:!!20 to 24 years']
ay_two_female['Total:!!Female:!!25 to 29 years'] + ay_two_female['Total:!!Female:!!30 to 34 years'] + ay_two_female['Total:!!Female:!!35 to 44 years'] + ay_two_female['Total:!!Female:!!45 to 54 years']
# Out:
# 0        11928
# 1         9893
# 2        31951
# 3         8956
# 4       292211
#         ...
# 260       5961
# 261      31200
# 262       3903
# 263      61938
# 264    2981857
# Length: 265, dtype: int32

# %%
ay_two_female = ay_two_female[['Label (Grouping)','Total:','two_female_pop_15_54','year']].rename(columns = {'Label (Grouping)':'state','Total:':'two_total_pop'})

# %% [markdown]
# ## MERGE ALL DEMO'S

# %%
data_frames = [ay_two_female,ay_nhopi_female,ay_asian_female,ay_aian_female,ay_aa_female,ay_yt_female,ay_his_female]

# %%
#all_years_female_demo = pd.concat([ay_two_female,ay_nhopi_female,ay_asian_female,ay_aian_female,ay_aa_female,ay_yt_female,ay_his_female]).reset_index(drop=True)

# %%
#all_years_female_demo.to_csv('all_years_female_demo.csv')

# %%
ay_two_female.to_csv('ay_two_female.csv')
ay_nhopi_female.to_csv('ay_nhopi_female.csv')
ay_asian_female.to_csv('ay_asian_female.csv')
ay_aian_female.to_csv('ay_aian_female.csv')
ay_aa_female.to_csv('ay_aa_female.csv')
ay_yt_female.to_csv('ay_yt_female.csv')
ay_his_female.to_csv('ay_his_female.csv')
